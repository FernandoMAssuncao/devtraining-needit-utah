# %% [markdown]
# <a href="https://colab.research.google.com/github/FernandoMAssuncao/devtraining-needit-utah/blob/main/C%C3%B3pia_de_Imers%C3%A3o_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Aula 2 Importação

# %%
import pandas as pd

# %%
df_principal = pd.read_excel("/Imersao_Alura.xlsx", sheet_name = "Principal")
df_principal
# Out:
#     Ativo       Data  Último (R$)  Var. Dia (%)  Var. Sem. (%)  Var. Mês (%)  \
# 0   USIM5  1/26/2024         9.50          5.20          11.76          2.26
# 1   CMIN3  1/26/2024         6.82          2.40           2.40        -12.11
# 2   PETR3  1/26/2024        41.96          2.19           7.73          7.64
# 3   SUZB3  1/26/2024        52.91          2.04           2.14         -4.89
# 4   CPFE3  1/26/2024        37.10          2.03           2.49         -3.66
# ..    ...        ...          ...           ...            ...           ...
# 76  CRFB3  1/26/2024        10.71         -2.45          -9.47        -13.98
# 77  BHIA3  1/26/2024         8.70         -2.46          -6.95        -23.55
# 78  RENT3  1/26/2024        56.24         -3.63          -6.41        -11.57
# 79  CVCB3  1/26/2024         3.07         -4.36          -5.54        -12.29
# 80  GOLL4  1/26/2024         5.92         -8.07         -15.91        -34.00
#
# ...

# %%
df_Total_de_acoes = pd.read_excel("/Imersao_Alura.xlsx", sheet_name = "Total_de_acoes")
df_Total_de_acoes
# Out:
#                       Código  Qtde. Teórica
# 0                      RRRP3   2.356656e+08
# 1                      ALOS3   5.326166e+08
# 2                      ALPA4   1.767340e+08
# 3                      ABEV3   4.394246e+09
# 4                      ARZZ3   6.230589e+07
# ..                       ...            ...
# 84                     VBBR3   1.114413e+09
# 85                     WEGE3   1.481593e+09
# 86                     YDUQ3   2.893479e+08
# 87  Quantidade Teórica Total   9.637210e+10
# 88                   Redutor   1.704785e+07
#
# [89 rows x 2 columns]

# %%
df_Ticker = pd.read_excel("/Imersao_Alura.xlsx", sheet_name = "Ticker")
df_Ticker
# Out:
#     Ticker            Nome
# 0    MGLU3  Magazine Luiza
# 1    HAPV3         Hapvida
# 2    PETR4       Petrobras
# 3    B3SA3              B3
# 4    USIM5        Usiminas
# ..     ...             ...
# 530  TKNO3           Tekno
# 531  COCE6          Coelce
# 532  MGEL3         Mangels
# 533  CTSA8      Santanense
# 534  MMAQ4   Minasmáquinas
#
# [535 rows x 2 columns]

# %%
df_ChatGPT = pd.read_excel("/Imersao_Alura.xlsx", sheet_name = "ChatGPT")
df_ChatGPT
# Out:
#              Empresa Idade (em anos)           Segmento
# 0           Usiminas              60         Siderurgia
# 1      CSN Mineração              13          Mineração
# 2          Petrobras              69     Petróleo e Gás
# 3             Suzano              98   Papel e Celulose
# 4       CPFL Energia             109   Energia Elétrica
# ..               ...             ...                ...
# 73  Carrefour Brasil              47             Varejo
# 74       Casas Bahia              63             Varejo
# 75          Localiza              49  Aluguel de Carros
# 76               CVC              48            Turismo
# 77               GOL              21   Transporte Aéreo
#
# [78 rows x 3 columns]
